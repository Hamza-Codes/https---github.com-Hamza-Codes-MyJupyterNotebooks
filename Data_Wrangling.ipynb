# %% [markdown]
# # Data Wrangling
# ---

# %% [markdown]
# ##### Cleaning the data with three methods.
#
# 1. Droping the NA Values
# 2. Replacing the Missing Values with the Average of that Column

# %% [markdown]
# ### 1. Droping the N/A Values from the Dataframes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
kashti  = sns.load_dataset("titanic")

ks1 = sns.load_dataset("titanic")
ks2 = sns.load_dataset("titanic")
ks3 = sns.load_dataset("titanic")
ks4 = sns.load_dataset("titanic")

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# math operations on the cloumn
(kashti['age']+12).head(10)
# Out:
# 0    34.0
# 1    50.0
# 2    38.0
# 3    47.0
# 4    47.0
# 5     NaN
# 6    66.0
# 7    14.0
# 8    39.0
# 9    26.0
# Name: age, dtype: float64

# %%
kashti.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
print(kashti.shape)
# Out:
# (891, 15)

# %%
# remove null data from the deck column 

kashti.dropna(subset=['deck'],axis=0,inplace=True)

# %%
kashti.shape
kashti.isnull().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %%
kashti = kashti.dropna()
kashti.isnull().sum() # remove na from the whole dataset
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
kashti.shape
# Out:
# (182, 15)

# %%
kashti.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %% [markdown]
# ### 2. Replacing Missing Values with the Average of that Column

# %%
print(ks1)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ks1.shape
# Out:
# (891, 15)

# %%
ks1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
mean = ks1['age'].mean()
mean
# Out:
# 29.69911764705882

# %%
ks1['age'] = ks1['age'].replace(np.nan,mean)

# %%
ks1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
ks1['age']
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
ks1['age']=ks1['age']*365
ks1.head(10)
# Out:
#    survived  pclass     sex           age  sibsp  parch     fare embarked  \
# 0         0       3    male   8030.000000      1      0   7.2500        S
# 1         1       1  female  13870.000000      1      0  71.2833        C
# 2         1       3  female   9490.000000      0      0   7.9250        S
# 3         1       1  female  12775.000000      1      0  53.1000        S
# 4         0       3    male  12775.000000      0      0   8.0500        S
# 5         0       3    male  10840.177941      0      0   8.4583        Q
# 6         0       1    male  19710.000000      0      0  51.8625        S
# 7         0       3    male    730.000000      3      1  21.0750        S
# 8         1       3  female   9855.000000      0      2  11.1333        S
# 9         1       2  female   5110.000000      1      0  30.0708        C
#
#     class    who  adult_male deck  embark_town alive  alone
# 0   Third    man        True  NaN  Southampton    no  False
# ...

# %%
ks1.rename(columns={'age':'age in days'},inplace=True)

# %%
ks1.head()
# Out:
#    survived  pclass     sex  age in days  sibsp  parch     fare embarked  \
# 0         0       3    male       8030.0      1      0   7.2500        S
# 1         1       1  female      13870.0      1      0  71.2833        C
# 2         1       3  female       9490.0      0      0   7.9250        S
# 3         1       1  female      12775.0      1      0  53.1000        S
# 4         0       3    male      12775.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Data Normalisation

# %%
ks2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
ks2= ks1[['age in days','fare']]
ks2
# Out:
#       age in days     fare
# 0     8030.000000   7.2500
# 1    13870.000000  71.2833
# 2     9490.000000   7.9250
# 3    12775.000000  53.1000
# 4    12775.000000   8.0500
# ..            ...      ...
# 886   9855.000000  13.0000
# 887   6935.000000  30.0000
# 888  10840.177941  23.4500
# 889   9490.000000  30.0000
# 890  11680.000000   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# ### Method of Normalisation
#
# 1. Simple Feature Scaling
#    1. x(new) = x(old)/x(max)
# 2. Min-Max Method
# 3. Z-Score (Standard Score) -3 to +3
# 4. Log Transformation

# %%
# Simple Transformation

ks2 ['fare'] = ks2['fare']/ks2['fare'].max()
ks2 ['age in days'] = ks2['age in days']/ks2['age in days'].max()
ks2.head()
# Out:
#    age in days      fare
# 0       0.2750  0.014151
# 1       0.4750  0.139136
# 2       0.3250  0.015469
# 3       0.4375  0.103644
# 4       0.4375  0.015713

# %% [markdown]
# ### Min - Max Method

# %%
ks3['fare'] = (ks3['fare']-ks3['fare'].min())/(ks3['fare'].max()-ks3['fare'].min())
ks3.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  22.0      1      0  0.014151        S  Third
# 1         1       1  female  38.0      1      0  0.139136        C  First
# 2         1       3  female  26.0      0      0  0.015469        S  Third
# 3         1       1  female  35.0      1      0  0.103644        S  First
# 4         0       3    male  35.0      0      0  0.015713        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Z-score Method

# %%
ks4['fare'] = (ks4['fare']-ks4['fare'].mean()) / ks4['fare'].std()
ks4.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  22.0      1      0 -0.502163        S  Third
# 1         1       1  female  38.0      1      0  0.786404        C  First
# 2         1       3  female  26.0      0      0 -0.488580        S  Third
# 3         1       1  female  35.0      1      0  0.420494        S  First
# 4         0       3    male  35.0      0      0 -0.486064        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
